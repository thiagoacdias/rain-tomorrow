# %%
import pandas as pd
import numpy as np

from pandas_profiling import ProfileReport
from pycaret.classification import *
from pycaret.datasets import get_data

# %%
df_credit = pd.DataFrame(get_data('credit'))
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0      20000    2          2         1  ...       0.0       0.0       0.0        1
# 1      90000    2          2         2  ...    1000.0    1000.0    5000.0        0
# 2      50000    2          2         1  ...    1100.0    1069.0    1000.0        0
# 3      50000    1          2         1  ...    9000.0     689.0     679.0        0
# 4      50000    1          1         2  ...    1000.0    1000.0     800.0        0
#
# [5 rows x 24 columns]

# %%
setup(data=df_credit, target='default')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_084ca4cc_08d7_11eb_babe_2816ad2a9111" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_084ca4cc_08d7_11eb_babe_2816ad2a9111level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_084ca4cc_08d7_11eb_babe_2816ad2a9111row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_084ca4cc_08d7_11eb_babe_2816ad2a9111row0_col1" class="data row0 col1" >5588</td>
#             </tr>
#             <tr>
#                         <th id="T_084ca4cc_08d7_11eb_babe_2816ad2a9111level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_084ca4cc_08d7_11eb_babe_2816ad2a9111row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
crea
